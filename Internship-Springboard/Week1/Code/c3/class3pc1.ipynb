# %%
import os
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\Internship-Springboard\Internship-Springboard\Week1\Code\c3

# %%
import pandas as pd
#df = pd.read_csv('../../dataset/tweet csv/chatGPT.csv', encoding='utf-8')
df = pd.read_csv("tweets.csv", encoding="utf-8")

# %%
print(df.head())
# Out:
#       author                                            content country  \
# 0  katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1  katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2  katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3  katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4  katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
#
#           date_time            id language  latitude  longitude  \
# 0  12-01-2017 19:52  8.200000e+17       en       NaN        NaN
# 1  11-01-2017 08:38  8.190000e+17       en       NaN        NaN
# 2  11-01-2017 02:52  8.190000e+17       en       NaN        NaN
# 3  11-01-2017 02:44  8.190000e+17       en       NaN        NaN
# 4  10-01-2017 05:22  8.190000e+17       en       NaN        NaN
#
#    number_of_likes  number_of_shares
# 0             7900              3472
# 1             3689              1380
# ...

# %%
df.count()
# Out:
# author              52542
# content             52542
# country                37
# date_time           52542
# id                  52542
# language            52542
# latitude                1
# longitude               1
# number_of_likes     52542
# number_of_shares    52542
# dtype: int64
